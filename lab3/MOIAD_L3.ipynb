# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd # загружаем библиотеку и для простоты обращения в коде называем её сокращенно pd

# %%
import matplotlib.pyplot as plt # загружаем библиотеку и для простоты обращения в коде называем её сокращенно plt

# позволяет отображать графики прямо в ноутбуке
# %matplotlib inline

# %%
training_data = pd.read_csv('garments_worker_productivity.csv')
training_data.head(10)
# Out:
#        date   quarter  department       day  team  targeted_productivity  \
# 0  1/1/2015  Quarter1      sweing  Thursday     8                   0.80
# 1  1/1/2015  Quarter1  finishing   Thursday     1                   0.75
# 2  1/1/2015  Quarter1      sweing  Thursday    11                   0.80
# 3  1/1/2015  Quarter1      sweing  Thursday    12                   0.80
# 4  1/1/2015  Quarter1      sweing  Thursday     6                   0.80
# 5  1/1/2015  Quarter1      sweing  Thursday     7                   0.80
# 6  1/1/2015  Quarter1  finishing   Thursday     2                   0.75
# 7  1/1/2015  Quarter1      sweing  Thursday     3                   0.75
# 8  1/1/2015  Quarter1      sweing  Thursday     2                   0.75
# 9  1/1/2015  Quarter1      sweing  Thursday     1                   0.75
#
#      smv     wip  over_time  incentive  idle_time  idle_men  \
# 0  26.16  1108.0       7080         98        0.0         0
# 1   3.94     NaN        960          0        0.0         0
# 2  11.41   968.0       3660         50        0.0         0
# 3  11.41   968.0       3660         50        0.0         0
# 4  25.90  1170.0       1920         50        0.0         0
# 5  25.90   984.0       6720         38        0.0         0
# 6   3.94     NaN        960          0        0.0         0
# 7  28.08   795.0       6900         45        0.0         0
# 8  19.87   733.0       6000         34        0.0         0
# 9  28.08   681.0       6900         45        0.0         0
#
#    no_of_style_change  no_of_workers  actual_productivity
# 0                   0           59.0             0.940725
# 1                   0            8.0             0.886500
# 2                   0           30.5             0.800570
# 3                   0           30.5             0.800570
# 4                   0           56.0             0.800382
# 5                   0           56.0             0.800125
# 6                   0            8.0             0.755167
# 7                   0           57.5             0.753683
# 8                   0           55.0             0.753098
# 9                   0           57.5             0.750428

# %%
training_data.shape
# Out:
# (1197, 15)

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    691 non-null    float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
#  14  actual_productivity    1197 non-null   float64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 140.4+ KB

# %%
training_data = training_data.dropna()

# %%
training_data.shape
# Out:
# (691, 15)

# %%
training_data.head()
# Out:
#        date   quarter department       day  team  targeted_productivity  \
# 0  1/1/2015  Quarter1     sweing  Thursday     8                    0.8
# 2  1/1/2015  Quarter1     sweing  Thursday    11                    0.8
# 3  1/1/2015  Quarter1     sweing  Thursday    12                    0.8
# 4  1/1/2015  Quarter1     sweing  Thursday     6                    0.8
# 5  1/1/2015  Quarter1     sweing  Thursday     7                    0.8
#
#      smv     wip  over_time  incentive  idle_time  idle_men  \
# 0  26.16  1108.0       7080         98        0.0         0
# 2  11.41   968.0       3660         50        0.0         0
# 3  11.41   968.0       3660         50        0.0         0
# 4  25.90  1170.0       1920         50        0.0         0
# 5  25.90   984.0       6720         38        0.0         0
#
#    no_of_style_change  no_of_workers  actual_productivity
# 0                   0           59.0             0.940725
# 2                   0           30.5             0.800570
# 3                   0           30.5             0.800570
# 4                   0           56.0             0.800382
# 5                   0           56.0             0.800125

# %%
training_values2 = training_data['targeted_productivity']

# %%
training_points2 = training_data.drop('targeted_productivity', axis=1)

# %%
training_points2.head()
# Out:
#        date   quarter department       day  team    smv     wip  over_time  \
# 0  1/1/2015  Quarter1     sweing  Thursday     8  26.16  1108.0       7080
# 2  1/1/2015  Quarter1     sweing  Thursday    11  11.41   968.0       3660
# 3  1/1/2015  Quarter1     sweing  Thursday    12  11.41   968.0       3660
# 4  1/1/2015  Quarter1     sweing  Thursday     6  25.90  1170.0       1920
# 5  1/1/2015  Quarter1     sweing  Thursday     7  25.90   984.0       6720
#
#    incentive  idle_time  idle_men  no_of_style_change  no_of_workers  \
# 0         98        0.0         0                   0           59.0
# 2         50        0.0         0                   0           30.5
# 3         50        0.0         0                   0           30.5
# 4         50        0.0         0                   0           56.0
# 5         38        0.0         0                   0           56.0
#
#    actual_productivity
# 0             0.940725
# 2             0.800570
# 3             0.800570
# 4             0.800382
# 5             0.800125

# %%
training_points2.shape
# Out:
# (691, 14)

# %%
from sklearn import linear_model, ensemble
linear_regression_model = linear_model.LinearRegression() # создаем модель
random_forest_model = ensemble.RandomForestRegressor(random_state=123)

# %%
#Удалим текстовые поля и поле с датой
training_points2 = training_points2.drop(['date', 'quarter', 'department', 'day', 'wip'], axis=1)

# %%
linear_regression_model.fit(training_points2, training_values2)
# Out:
# LinearRegression()

# %%
random_forest_model.fit(training_points2, training_values2)
# Out:
# RandomForestRegressor(random_state=123)

# %%
test_data = pd.read_csv('garments_worker_productivity.csv')
test_data.head(10)
# Out:
#        date   quarter  department       day  team  targeted_productivity  \
# 0  1/1/2015  Quarter1      sweing  Thursday     8                   0.80
# 1  1/1/2015  Quarter1  finishing   Thursday     1                   0.75
# 2  1/1/2015  Quarter1      sweing  Thursday    11                   0.80
# 3  1/1/2015  Quarter1      sweing  Thursday    12                   0.80
# 4  1/1/2015  Quarter1      sweing  Thursday     6                   0.80
# 5  1/1/2015  Quarter1      sweing  Thursday     7                   0.80
# 6  1/1/2015  Quarter1  finishing   Thursday     2                   0.75
# 7  1/1/2015  Quarter1      sweing  Thursday     3                   0.75
# 8  1/1/2015  Quarter1      sweing  Thursday     2                   0.75
# 9  1/1/2015  Quarter1      sweing  Thursday     1                   0.75
#
#      smv     wip  over_time  incentive  idle_time  idle_men  \
# 0  26.16  1108.0       7080         98        0.0         0
# 1   3.94     NaN        960          0        0.0         0
# 2  11.41   968.0       3660         50        0.0         0
# 3  11.41   968.0       3660         50        0.0         0
# 4  25.90  1170.0       1920         50        0.0         0
# 5  25.90   984.0       6720         38        0.0         0
# 6   3.94     NaN        960          0        0.0         0
# 7  28.08   795.0       6900         45        0.0         0
# 8  19.87   733.0       6000         34        0.0         0
# 9  28.08   681.0       6900         45        0.0         0
#
#    no_of_style_change  no_of_workers  actual_productivity
# 0                   0           59.0             0.940725
# 1                   0            8.0             0.886500
# 2                   0           30.5             0.800570
# 3                   0           30.5             0.800570
# 4                   0           56.0             0.800382
# 5                   0           56.0             0.800125
# 6                   0            8.0             0.755167
# 7                   0           57.5             0.753683
# 8                   0           55.0             0.753098
# 9                   0           57.5             0.750428

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    691 non-null    float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
#  14  actual_productivity    1197 non-null   float64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 140.4+ KB

# %%
test_data.head()
# Out:
#        date   quarter  department       day  team  targeted_productivity  \
# 0  1/1/2015  Quarter1      sweing  Thursday     8                   0.80
# 1  1/1/2015  Quarter1  finishing   Thursday     1                   0.75
# 2  1/1/2015  Quarter1      sweing  Thursday    11                   0.80
# 3  1/1/2015  Quarter1      sweing  Thursday    12                   0.80
# 4  1/1/2015  Quarter1      sweing  Thursday     6                   0.80
#
#      smv     wip  over_time  incentive  idle_time  idle_men  \
# 0  26.16  1108.0       7080         98        0.0         0
# 1   3.94     NaN        960          0        0.0         0
# 2  11.41   968.0       3660         50        0.0         0
# 3  11.41   968.0       3660         50        0.0         0
# 4  25.90  1170.0       1920         50        0.0         0
#
#    no_of_style_change  no_of_workers  actual_productivity
# 0                   0           59.0             0.940725
# 1                   0            8.0             0.886500
# 2                   0           30.5             0.800570
# 3                   0           30.5             0.800570
# 4                   0           56.0             0.800382

# %%
test_values = test_data['targeted_productivity']
test_points = test_data.drop('targeted_productivity', axis=1)
test_points.head()
# Out:
#        date   quarter  department       day  team    smv     wip  over_time  \
# 0  1/1/2015  Quarter1      sweing  Thursday     8  26.16  1108.0       7080
# 1  1/1/2015  Quarter1  finishing   Thursday     1   3.94     NaN        960
# 2  1/1/2015  Quarter1      sweing  Thursday    11  11.41   968.0       3660
# 3  1/1/2015  Quarter1      sweing  Thursday    12  11.41   968.0       3660
# 4  1/1/2015  Quarter1      sweing  Thursday     6  25.90  1170.0       1920
#
#    incentive  idle_time  idle_men  no_of_style_change  no_of_workers  \
# 0         98        0.0         0                   0           59.0
# 1          0        0.0         0                   0            8.0
# 2         50        0.0         0                   0           30.5
# 3         50        0.0         0                   0           30.5
# 4         50        0.0         0                   0           56.0
#
#    actual_productivity
# 0             0.940725
# 1             0.886500
# 2             0.800570
# 3             0.800570
# 4             0.800382

# %%
test_points.shape
# Out:
# (1197, 14)

# %%
#Удалим текстовые поля и поле с датой
test_points = test_points.drop(['date', 'quarter', 'department', 'day', 'wip'], axis=1)

# %%
list(test_points)==list(training_points2)
# Out:
# True

# %%
test_predictions_linear = linear_regression_model.predict(test_points)
test_predictions_random_forest = random_forest_model.predict(test_points)

# %%
#линейная модель
plt.figure(figsize=(7, 7))
plt.scatter(test_values, test_predictions_linear) # рисуем точки, соответствущие парам настоящее значение - прогноз
plt.plot([0, max(test_values)], [0, max(test_predictions_linear)])  # рисуем прямую, на которой предсказания и настоящие значения совпадают
plt.xlabel('Настоящее значение', fontsize=20)
plt.ylabel('Предсказанное значение', fontsize=20);

# %%
#случайный лес
plt.figure(figsize=(7, 7))
plt.scatter(test_values, test_predictions_random_forest) # рисуем точки, соответствущие парам настоящее значение - прогноз
plt.plot([0, max(test_values)], [0, max(test_predictions_random_forest)]) # рисуем прямую, на которой предсказания и настоящие значения совпадают
plt.xlabel('Настоящее значение', fontsize=20)
plt.ylabel('Предсказанное значение', fontsize=20);

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mean_absolute_error_linear_model = mean_absolute_error(test_values, test_predictions_linear)
mean_squared_error_linear_model = mean_squared_error(test_values, test_predictions_linear)
r2_score_linear_model = r2_score(test_values, test_predictions_linear)

# %%
mean_absolute_error_random_forest_model = mean_absolute_error(test_values, test_predictions_random_forest)
mean_squared_error_random_forest_model = mean_squared_error(test_values, test_predictions_random_forest)
r2_score_random_forest_model = r2_score(test_values, test_predictions_random_forest)

# %%
print("MAE: {0:7.2f}, RMSE: {1:7.2f}, R2: {2:7.2f} for linear model".format(
        mean_absolute_error(test_values, test_predictions_linear), 
        mean_squared_error(test_values, test_predictions_linear)**0.5, r2_score_linear_model))

print("MAE: {0:7.2f}, RMSE: {1:7.2f},  R2: {2:7.2f} for random forest model".format(
       mean_absolute_error(test_values, test_predictions_random_forest), 
       mean_squared_error(test_values, test_predictions_random_forest)**0.5, r2_score_random_forest_model))
# Out:
# MAE:    0.08, RMSE:    0.16, R2:   -1.68 for linear model
# MAE:    0.04, RMSE:    0.08,  R2:    0.31 for random forest model
